# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Loading the CSV file
master_df = pd.read_csv('master_dataset.csv')

column_types_1 = {12: str, 13: str, 14: str, 15: str}
fatal_crash_df = pd.read_csv('BITRE_Fatal_Crash_5_49624_A_T.csv', dtype=column_types_1)
fatal_crash_count_df = pd.read_csv('BITRE_Fatal_Crash_Count_By_Date_3_12633_A_E.csv')

column_types_2 = {14: str, 15: str, 16: str, 17: str, }
fatalities_df = pd.read_csv('BITRE_Fatality_5_55052_A_W.csv', dtype=column_types_2)
fatalities_count_df = pd.read_csv('BITRE_Fatality_Count_By_Date_3_12633_A_E.csv')

# Merging the two dataframes
common_columns = [col for col in fatal_crash_df.columns if col in fatalities_df.columns and col != 'Crash ID']
fatal_crash_df.drop(columns=common_columns, inplace=True)
fatalities_df = pd.merge(fatalities_df, fatal_crash_df, on='Crash ID', how='inner')

# Filtering to NSW only
nsw_fatalities = fatalities_df[fatalities_df['State'] == "NSW"]

# %%
nsw_kid_fatalities = nsw_fatalities[(nsw_fatalities['Age'] >= 12) & (nsw_fatalities['Age'] <= 18)]

# %%
nsw_kid_fatalities.head()
# Out:
#      Crash ID State  Month  Year    Dayweek      Time Crash Type  \
# 3    20231131   NSW      7  2023     Friday  18:00:00   Multiple
# 24   20231146   NSW      7  2023     Sunday  12:40:00   Multiple
# 46   20231125   NSW      7  2023  Wednesday  08:40:00   Multiple
# 111  20231032   NSW      6  2023     Friday  18:30:00     Single
# 123  20231129   NSW      6  2023     Sunday  00:59:00     Single
#
#     Bus Involvement Heavy Rigid Truck Involvement  \
# 3                No                            No
# 24               No                            No
# 46               No                           Yes
# 111              No                            No
# 123              No                            No
#
#     Articulated Truck Involvement  ...  National LGA Name 2021  \
# 3                              No  ...          Lake Macquarie
# 24                             No  ...                 Cabonne
# 46                            Yes  ...               Singleton
# ...

# %%
data.to_csv(output_file_name, index=False)

# %%
# print nsw_fatalities column names
print(nsw_fatalities.columns)
print(master_df.columns)
# Out:
# Index(['Crash ID', 'State', 'Month', 'Year', 'Dayweek', 'Time', 'Crash Type',
#        'Bus Involvement', 'Heavy Rigid Truck Involvement',
#        'Articulated Truck Involvement', 'Speed Limit', 'Road User', 'Gender',
#        'Age', 'National Remoteness Areas', 'SA4 Name 2021',
#        'National LGA Name 2021', 'National Road Type', 'Christmas Period',
#        'Easter Period', 'Age Group', 'Day of week', 'Time of day',
#        'Number Fatalities', 'Bus \nInvolvement', 'Time of Day'],
#       dtype='object')
# Index(['School_code', 'AgeID', 'School_name', 'Street', 'Town_suburb',
#        'Postcode', 'Phone', 'School_Email', 'Website', 'Fax',
#        'latest_year_enrolment_FTE', 'Indigenous_pct', 'LBOTE_pct',
#        'ICSEA_value', 'Level_of_schooling', 'Selective_school',
#        'Opportunity_class', 'School_specialty_type', 'School_subtype',
#        'Support_classes', 'Preschool_ind', 'Distance_education',
# ...

# %%
# print first entry in pandas df nsw_fatalities
print(nsw_fatalities.iloc[1000])
# Out:
# Crash ID                                          20201013
# State                                                  NSW
# Month                                                    3
# Year                                                  2020
# Dayweek                                          Wednesday
# Time                                              10:40:00
# Crash Type                                          Single
# Bus Involvement                                         No
# Heavy Rigid Truck Involvement                           No
# Articulated Truck Involvement                           No
# Speed Limit                                             60
# Road User                                           Driver
# Gender                                                Male
# Age                                                     74
# National Remoteness Areas        Major Cities of Australia
# SA4 Name 2021                    Sydney - Inner South West
# ...

# %%
print(nsw_fatalities["Number Fatalities"].unique())
print(len(nsw_fatalities[nsw_fatalities["Crash ID"] == 19891291]))
# Out:
# [ 1 10  2  4  3  5  6 35 20]
# 2
